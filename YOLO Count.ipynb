# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Model
#line = torch.hub.load("ultralytics/yolov5", "custom", path='/home/mohit.srivastava@Brightlifecare.local/FinalModel/detectron.pt')  
model = torch.hub.load("ultralytics/yolov5", "custom", path='/home/mohit.srivastava@Brightlifecare.local/FinalModel/ResurrectionWG.pt')

# Images
img = cv2.imread("/home/mohit.srivastava@Brightlifecare.local/cleaned_input/226.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Inference
results = model(img)
crops = results.crop(save=True)
if crops:
    print("TRUE")
#results.crop(save_dir="/home/mohit.srivastava@Brightlifecare.local/3_aug_test")

print(crops[0]['im'])
#results.show()
#x = results.pandas().xyxy[0]
#print(len(x))
# Out:
# Using cache found in /home/mohit.srivastava@Brightlifecare.local/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-3-19 Python-3.10.12 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# Saved 1 image to runs/detect/exp5
# Saved results to runs/detect/exp5
# TRUE
# [[[ 68 135 142]
#   [ 72 137 144]
#   [ 75 139 147]
#   ...
#   [154 214 255]
#   [153 214 255]
#   [153 214 255]]
#
#  [[ 67 132 140]
#   [ 69 133 142]
#   [ 73 135 144]
#   ...
#   [154 214 255]
#   [152 213 255]
#   [152 213 255]]
#
#  [[ 64 128 138]
#   [ 69 132 141]
#   [ 72 134 144]
#   ...
#   [154 214 255]
#   [152 213 255]
#   [152 213 255]]
#
#  ...
#
#  [[213 209 202]
#   [206 205 199]
#   [198 201 194]
#   ...
#   [167 166 178]
#   [167 166 178]
#   [170 169 180]]
#
#  [[205 203 196]
#   [191 193 186]
#   [171 177 170]
#   ...
#   [167 165 177]
#   [169 167 178]
#   [173 171 183]]
#
#  [[192 193 186]
# ...

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2

line = torch.hub.load("ultralytics/yolov5", "custom", path='/home/mohit.srivastava@Brightlifecare.local/FinalModel/LDV1.pt')  

im = crops[0]['im']
#im = cv2.imread("/home/mohit.srivastava@Brightlifecare.local/Pictures13/crops/precipitate/image0.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
line.conf = 0.5

results2 = line(im)
results2.show()

x = results2.pandas().xyxy[0]
print(len(x))
# Out:
# Using cache found in /home/mohit.srivastava@Brightlifecare.local/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2023-3-19 Python-3.10.12 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# <PIL.Image.Image image mode=RGB size=398x428 at 0x7F5469C61F60>
# 14

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
from IPython.display import SVG, display

url1="/home/mohit.srivastava@Brightlifecare.local/DDataset/Resurrection Models/ResurrectionWG/train_box_loss.svg"
url2="/home/mohit.srivastava@Brightlifecare.local/DDataset/Resurrection Models/ResurrectionWG/train_obj_loss.svg"

SVG(url1)
#SVG(url2)
